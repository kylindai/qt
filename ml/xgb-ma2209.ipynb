# %%
import numpy as np
import pandas as pd
import sqlalchemy

# %%
base_path = '/Users/yunhui/work/github/miaowa/ctp.miaowa.pro/ctp-gateway/data/'
db_path = base_path + 'Ticker.MA2209.ZCE.db'

db = sqlalchemy.create_engine('sqlite:///' + db_path)
df = pd.read_sql('MA2209_ZCE_20220706', db)

# %%
df.shape
# Out:
# (306, 23)

# %%
df.head()
# Out:
#    id             created            modified      symbol      date  \
# 0   1 2022-07-06 05:37:49 2022-07-06 05:37:49  MA2209.ZCE  20220706
# 1   2 2022-07-06 05:37:54 2022-07-06 05:37:54  MA2209.ZCE  20220706
# 2   3 2022-07-06 05:37:55 2022-07-06 05:37:55  MA2209.ZCE  20220706
# 3   4 2022-07-06 05:37:56 2022-07-06 05:37:56  MA2209.ZCE  20220706
# 4   5 2022-07-06 05:38:05 2022-07-06 05:38:05  MA2209.ZCE  20220706
#
#            time  open  high   low  close  ...  last  average  settle  \
# 0  13:37:32.000  2467  2707  2463   2463  ...  2463     2479       0
# 1  13:37:42.000  2467  2707  2463   2463  ...  2463     2479       0
# 2  13:37:53.000  2467  2707  2463   2463  ...  2463     2479       0
# 3  13:37:56.000  2467  2707  2463   2463  ...  2463     2479       0
# 4  13:38:04.000  2467  2707  2463   2463  ...  2463     2479       0
#
#    pre_close  pre_settle  pre_open_interest  ask1_price  ask1_volume  \
# ...

# %%
t = df['time']
t.value_counts()
# Out:
# 13:37:32.000    1
# 14:10:54.000    1
# 14:12:11.000    1
# 14:12:00.000    1
# 14:11:49.000    1
#                ..
# 13:53:39.000    1
# 13:53:29.000    1
# 13:53:18.000    1
# 13:53:07.000    1
# 14:31:04.000    1
# Name: time, Length: 306, dtype: int64

# %%
# check time data
