# %%
import scipy
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import mplfinance as mpf

for m in [scipy, np, pd, matplotlib, mpf]:
    print(m.__name__, m.__version__)

from scipy.signal import savgol_filter
from scipy.signal import argrelextrema
from scipy.signal import find_peaks

from funcs.factor_utils import FactorUtil
from funcs.plot_utils import PlotUtil
# Out:
# scipy 1.15.3
# numpy 1.26.4
# pandas 2.2.3
# matplotlib 3.10.1
# mplfinance 0.12.10b0

# %%
bar_df_1 = FactorUtil.get_bar_df('C2507_MIN_1', '20250506', '00:00:00', 349)
bar_df_1.head()
# Out:
#                           O       H       L       C      V        AP     AV  \
# ts
# 2025-05-06 09:00:00  2381.0  2381.0  2379.0  2379.0   2982  2380.669    260
# 2025-05-06 09:01:00  2381.0  2381.0  2368.0  2369.0  33150  2373.050  52507
# 2025-05-06 09:02:00  2369.0  2372.0  2367.0  2371.0  17799  2370.269  72912
# 2025-05-06 09:03:00  2370.0  2371.0  2367.0  2369.0  14297  2369.628  94932
# 2025-05-06 09:04:00  2368.0  2370.0  2366.0  2368.0   8472  2368.571  90258
#
#                            BP      BV
# ts
# 2025-05-06 09:00:00  2378.823    1115
# 2025-05-06 09:01:00  2371.629   43381
# 2025-05-06 09:02:00  2368.865   87282
# 2025-05-06 09:03:00  2368.105  137669
# 2025-05-06 09:04:00  2367.003  130169

# %%
PlotUtil.show_plot('C2507_MIN_1_20250506', bar_df_1)

# %%
bar_df_1.to_csv('./data/C2507_MIN_1_25050506.csv')

# %%
bar_df_2 = FactorUtil.get_bar_df('C2507_MIN_1', '20250507', '00:00:00', 349)
PlotUtil.show_plot('C2507_MIN_1_20250507', bar_df_2)
bar_df_2.to_csv('./data/C2507_MIN_1_25050507.csv')

# %%
bar_df_3 = FactorUtil.get_bar_df('C2507_MIN_1', '20250508', '00:00:00', 349)
PlotUtil.show_plot('C2507_MIN_1_20250508', bar_df_3)
bar_df_3.to_csv('./data/C2507_MIN_1_25050508.csv')

# %%
bar_df_4 = FactorUtil.get_bar_df('C2507_MIN_1', '20250509', '00:00:00', 349)
PlotUtil.show_plot('C2507_MIN_1_20250509', bar_df_4)
bar_df_4.to_csv('./data/C2507_MIN_1_25050509.csv')

# %%
bar_df_5 = FactorUtil.get_bar_df('C2507_MIN_1', '20250506')
PlotUtil.show_plot('C2507_MIN_1_20250506-20250509', bar_df_5, plot_type='line')
bar_df_5.to_csv('./data/C2507_MIN_1_20250506-20250509.csv')
