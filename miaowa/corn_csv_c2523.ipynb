# %%
import scipy
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import mplfinance as mpf

for m in [scipy, np, pd, matplotlib, mpf]:
    print(m.__name__, m.__version__)

from scipy.signal import savgol_filter
from scipy.signal import argrelextrema
from scipy.signal import find_peaks

from funcs.factor_utils import FactorUtil
from funcs.plot_utils import PlotUtil
# Out:
# scipy 1.15.3
# numpy 1.26.4
# pandas 2.2.3
# matplotlib 3.10.1
# mplfinance 0.12.10b0

# %%
bar_date = '20250519'
bar_df_1 = FactorUtil.get_bar_df('C2507_MIN_1', bar_date, '00:00:00', 349)
PlotUtil.show_plot(f'C2507_MIN_1_{bar_date}', bar_df_1)
bar_df_1.to_csv(f'./data/C2507_MIN_1_{bar_date}.csv')

# %%
bar_date = '20250520'
bar_df_2 = FactorUtil.get_bar_df('C2507_MIN_1', bar_date, '00:00:00', 349)
PlotUtil.show_plot(f'C2507_MIN_1_{bar_date}', bar_df_2)
bar_df_2.to_csv(f'./data/C2507_MIN_1_{bar_date}.csv')

# %%
bar_date = '20250521'
bar_df_3 = FactorUtil.get_bar_df('C2507_MIN_1', bar_date, '00:00:00', 349)
PlotUtil.show_plot(f'C2507_MIN_1_{bar_date}', bar_df_3)
bar_df_3.to_csv(f'./data/C2507_MIN_1_{bar_date}.csv')

# %%
bar_date = '20250522'
bar_df_4 = FactorUtil.get_bar_df('C2507_MIN_1', bar_date, '00:00:00', 349)
PlotUtil.show_plot(f'C2507_MIN_1_{bar_date}', bar_df_4)
bar_df_4.to_csv(f'./data/C2507_MIN_1_{bar_date}.csv')

# %%
bar_date = '20250523'
bar_df_5 = FactorUtil.get_bar_df('C2507_MIN_1', bar_date, '00:00:00', 349)
PlotUtil.show_plot(f'C2507_MIN_1_{bar_date}', bar_df_5)
bar_df_5.to_csv(f'./data/C2507_MIN_1_{bar_date}.csv')

# %%
bar_df_6 = FactorUtil.get_bar_df('C2507_MIN_1', '20250519')
PlotUtil.show_plot('C2507_MIN_1_20250519-20250523', bar_df_6, plot_type='line')
bar_df_6.to_csv('./data/C2507_MIN_1_20250519-20250523.csv')

# %%
bar_df_7 = FactorUtil.get_bar_df('C2507_MIN_2', '20250519')
PlotUtil.show_plot('C2507_MIN_2_20250519-20250523', bar_df_7, plot_type='line')
bar_df_7.to_csv('./data/C2507_MIN_2_20250519-20250523.csv')

# %%
bar_df_8 = FactorUtil.get_bar_df('C2507_MIN_3', '20250519')
PlotUtil.show_plot('C2507_MIN_3_20250519-20250523', bar_df_8, plot_type='line')
bar_df_8.to_csv('./data/C2507_MIN_3_20250519-20250523.csv')
